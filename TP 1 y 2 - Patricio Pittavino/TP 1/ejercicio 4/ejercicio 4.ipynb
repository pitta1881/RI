# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\pitta\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\pitta\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\pitta\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from itertools import zip_longest
from nltk.stem import PorterStemmer, LancasterStemmer
import os
import sys
sys.path.append(os.path.abspath("../../shared"))  # Agrega la carpeta al PYTHONPATH
from tokenizer_v2 import tokenizer, useStemmer

# %%
CISI_FILE = '../cisi/CISI.ALL'
MAX_LONG = 20
MIN_LONG = 3
porter_stemmer = PorterStemmer()
lancaster_stemmer = LancasterStemmer()

# %%
def process_file(file: str, stemmer):
    content = ''
    with open(os.path.abspath(file), 'r', encoding='utf8') as f:
        content += f.read()
    terms = useStemmer(stemmer, tokenizer(content))
    unique_words = set(terms)
    counter_unique_tokens = 0
    for word in unique_words:
        counter_unique_tokens += 1 if terms.count(word) == 1 else 0 
    return counter_unique_tokens, unique_words

# %%
counter_unique_tokens_porter, unique_words_porter = process_file(CISI_FILE, 'porter')

# %%
counter_unique_tokens_lancaster, unique_words_lancaster = process_file(CISI_FILE, 'lancaster')

# %%
print(f'Tokens unicos Porter: {counter_unique_tokens_porter}')
print(f'Tokens unicos Lancaster: {counter_unique_tokens_lancaster}')
# Out:
# Tokens unicos Porter: 5273
# Tokens unicos Lancaster: 4900

# %% [markdown]
# Podemos deducir que el algoritmo de Lancaster es mejor tanto en tiempo de ejecución (8.6s vs 7.7s) como en tokens únicos detectados (4157 vs 3677).

# %%
for word_porter, word_lancaster in zip_longest(unique_words_porter, unique_words_lancaster, fillvalue=''):
    print(word_porter, word_lancaster)
# Out:
# denot jahod
# devic denot
# termin termin
# 475 serial use
# concurr 475
# general technolog drot
# throughout adv
# ceas throughout
# schiminovich ceas
# edmundson schiminovich
# per edmundson
# salmon per
# germani salmon
# paradigmat coffm
# break excerpta medic
# channel break
# chemical abstracts service registry system channel
# anoth chemical abstracts service registry system
# anthropological theori anoth
# discard discard
# v.i v.i
# international aspect every
# packet packet
# r.r r.r
# methyl methyl
# dorfmann config
# computer search center statist fraud
# 865 information user
# jack
# wilson 865
# the test jack
# wilson
# session specific subjects
# congress bibliographical data congress bibliographical data
# india the prognostication
# 1054 estimating future demand levels
# 779 1054
# 566 779
# professional societi 566
# fritz milkau their organization
# medical librarianship fritz milkau
# modern integral information system assocy
# 593 medical librarianship
# text bibliographic retrieval system 593
# fourteen text bibliographic retrieval system
# speedili fourteen
# information seek dean jesse
# american cataloging
# rul duplication policy
# factors affect compact storage
# 473 473
# studer automated language processing
# improperli 1933
# militar ctot
# least cost decision rul vocabulary building
# 1933 232
# convinc 371
# 232 501
# 371 substitut
# 501 bookstack
# substitut l.d
# bookstack 817
# coleman m.r
# l.d 2740
# brodman then
# 817 enthusiast
# inabl bryc
# m.r shneerson
# 2740 a.g.
# then wil
# dexter 1190
# document dissemin 417
# patent citation index malinconico
# enthusiast strakhov
# underli 1970
# shneerson incompet
# 1190 large shared banks
# rectangular cancel
# concept system daugherty
# 417 albert james
# malinconico has
# strakhov stag
# hooker drum
# project manag fad
# the confer distaff
# ancient steel
# 1970 554
# incompet depr
# bell laboratori business study
# cancel information indexing
# distaff the cost analysis
# drum lexicograph
# public knowledge
# an essay concern hein
# lauren architectural issues
# steel hayn
# 554 information need
# vocat prim
# human factor kur
# lexicograph parallel
# hein catalog records
# there privileg
# hayn library catalog cards produced
# privileg duke university
# parallel grad
# new form athene
# charett company
# interactive retriev gdr
# the georgia tech librari 1335
# valenc psycholog
# gdr 168
# 1335 compon
# yorka 656
# psycholog detrib
# 168 microstruct
# compon himself
# central
# methodist college librari wail
# enter 254
# our commiss cooperative serial acquisition program
# 656 aft
# boulder laboratori reciproc
# detrib disp
# two paradigm imprint
# causal unfair
# himself partak
# authoritarian wojciechowsk
# wail size academic libraries
# 254 416
# cooperative serial acquisition program developing computer catalogs
# reciproc isaac
# unfair 772
# imprint stenstrom
# partak ready
# unref its operating efficiency
# bryce 55
# 416 schultz
# accident the distribution
# historical introduct theoretical semantics
# bioscienc 1019
# isaac reference scattering
# etr 12
# library interfac reserv
# manpower suppli what is it
# recogniz social mobility
# 772 bibliographical data
# stenstrom ory
# ephemer donald
# 55 profil
# american overseas library technical assist conscy
# information flow system tremend
# schultz resp
# liederman blld
# 1019 isenson
# the direct nonf
# 12 921
# reserv card
# what is it school
# bibliographical data bertalanffy
# centuri rehabilit
# cincinnati publ abraham
# swanson
# donald understanding scientific literatures
# profil gifford
# tremend bernshtein
# resp current medical terminalogy
# blld macro
# isenson scal
# 921 mass spectrometry
# card the index chemicus registry system
# moral decen
# criteria us 1136
# school forrest
# groups
# employing free languag new scheme
# rehabilit citation data
# dissens supply
# abraham
# swanson lesk
# gifford dang
# bernshtein 545
# interlibrary commun equifrequ
# politician paris principle
# macro the evaluation
# furnitur relational model
# experi feldm
# the paradox har
# bonn diseas
# the index chemicus registry system feedback
# 1136 hold
# forrest elrod
# citation data 1973
# grante 500
# seeker journals most cited
# large library operations us hedg
# lesk 1161
# unverifi 1929
# the euratom thesauru metropolitan public library
# secondary scientific publ 1092
# 545 rachel
# equifrequ clinician search
# bibliographic coupl colorado academic
# libraries book processing center
# selecting materi dorothy
# syntagmat asterisk
# relational model 279
# the universal decimal classif vind
# diseas soviet
# feedback incomp
# hold gier
# an interactive guid hypothet
# elrod complet
# 1973 technical services cost committee
# 500 technical problems
# priori futil
# hedg structuring
# 1161 logical jumps
# 1929 mittm
# preced research system description
# research institut clear
# 1092 484
# rachel undergon
# the area specialist bibliograph on selecting
# clinician search as mr
# bone blasingam
# asterisk resolved disagreements
#    about answer
# 279 parol
# v. public service
# ucla posit
# vital surfeit
# reference scatt social behavior
# european atomic energy commun weisgerb
# soviet fascic
# direct access system preoccup
# gier cart
# hypothet n.b
# complet c.h
# urgent stud
# preliminary studi reichman
# index medicu 858
# futil lss
# journal us bipol
# clear splitting
# 484 e.j
# hamdi wilkin
# undergon effectiveness analys
# as mr merg
# blasingam verner clapp
# immedi 843
# markusova going
# parol 441
# posit expend
# surfeit compl
# social behavior fict
# weisgerb 337
# preoccup piaget
# n.b penelop
# c.h situ
# enunci seen
# 858 careless
# library funct haunt
# stratif integ
# lss 344
# lister proofslip
# skydiv meet
# kilgour paper deacidification
# opinion pap the bottomless pit
# e.j published articles
# wilkin consum
# miscellan facet
# merg j.t
# verner clapp revolv
# 843 sparck
# medical school library statist 196
# 441 fingertip
# triphenylmethan new tasks
# faculty awar the scientist versus machine search services
# motiv input
# vertic electronic data processing
# narayan zholkovski
# expend outgrown
# 337 retir
# mobil large data bases
# asca hamilton
# shell 123
# piaget hud
# system development corpor an international mass spectral search system
# fine soph
# penelop herit
# kaplan raw
# seen interactive searching
# careless mei
# haunt stueart
# general descript preprocess
# integ wadex
# cost effect e.h
# 344 freshm
# barr exet
# proofslip guarantee
# meet microbiolog
# reapprais expens
# the bottomless pit investig
# premis subject headings
# plenary meet 1750
# cooper index chemicus
# consum woodford
# facet erich
# thesaurus construct d.w
# j.t 911
# sparck 826
# dormitori retrieval systems appropriate
# 196 entrust
# fingertip barbara
# weil
# naranan length
# input cataloque entries
# chernyavskii library trends
# transient friedland
# outgrown chauvenet
# retir gush
# hamilton dot
# basic 171
# 123 josephin
# hud 920
# an international mass spectral search system analyst
# great information network prospects
# broaden corrob
# scientific information set 335
# plastics data bas 600
# grolier strange
# data compress herm
# raw robert ardrey
# recaptur community systems foundation
# zaltman slav
# stueart manuscrib
# wadex photocomposit
# e.h as director
# viabil the association
# exet enlarg
# microbiolog commod
# expens nonbenz
# investig kov
# 1750 basic journal list
# snell rend
# woodford graft
# erich de solla pric
# d.w stereochemically unique naming algorithm
# 911 microphotograph
# 826 patterson
# wiswesser not crawford
# entrust 245
# intergovernment invisible college phenomenon
# barbara
# weil bookkeep
# length moscow
# friedland consol
# chauvenet yale medical library
# user assess ugc
# dot 1006
# 171 p.j
# josephin zuckerm
# scientific disciplin chos
# 920 catalog users
# alreadi convert
# analyst 539
# fizika 990
# 335 atmosph
# 600 696
# the bibliograph syntol
# blindli cran
# unidentifi robin
# loughborough univers higher education act
# robert ardrey capability
# index
# amelior confab
# cuarda haphazard
# photocomposit 5020
# as director t.r
# enlarg 62
# selected bibliographi made book collections
# commod gear
# meredith incomplet
# iitri gard
# basic journal list 1043
# graft comparative efficiency
# de solla pric 392
# excerpta medica 1073
# stereochemically unique naming algorithm unfortun
# patterson levin
# crawford push
# 245 proclaim
# invisible college phenomenon 366
# bookkeep year
# moscow bottl
# boolean strategi solid
# consol fright
# development circumspect
# ugc a.g
# 1006 manpower training
# p.j stobaugh
# heavily used biomedical journ the viability
# adi but
# sir thomas bodley
# psychological abstract 909
# crad divis vice president
# on select stev
# convert schedule
# 539 dem
# 990 380
# small medical librari retrieval effectiveness
# classification practic readable bibliographic
# data bases
# revolut hoyl
# 696 scientific fields
# the consist outgrow
# automated keyword classif cbac
# syntol surfac
# robin 1279
# quillian r.s
# higher education act 1963
# capability
# index adh
# blagden first step towards
# 5020 granito
# t.r fuzzy
# syntagmatic relations between descriptor unev
# 62 682
# gear the medical library assistance act
# incomplet current awareness searches
# tarski mostel
# social science literature us s.w
# action stil
# gard memb
# 1043 ongo
# dichotomi lingu
# 392 verisimilitud
# time 1231
# 1073 rate distortion theory
# unfortun quart
# levin impedy
# new york public librari 297
# push david dews
# proclaim perhap
# 366 outworn
# feasibility studi von
# year dna
# bottl scientific serials
# solid use mad
# american cataloging rul gotlieb
# circumspect wra
# document surrog pamel
# a.g ross
# evidenc 169
# the parametric descript united states
# stobaugh proverb
# but
# sir thomas bodley some scientific
# 909 centre national
# six new
# england state univers carvil
# concaten mass observation
# aural step
# aslib research
# depart lefev
# 380 ju
# xhigness cum
# surfac fiss
# hoyl impl
# cbac personalized service
# 1279 cle
# 1963 berny
# axiomat urb
# cagan canad
# defenc jessic
# granito theoretical foundations
# 682 thesaurus compilation method
# the medical library assistance act 641
# delici zim
# natur chronological
# mostel 2104
# length prop wendy
# s.w ayr
# ongo yale medical
# library
# part
# interlibrari attitudes toward academic library reference service
# reaction 598
# verisimilitud airpl
# generic medium design sam
# rarefi lag
# 1231 facsimil
# 297 468
# miracl mel
# expenditur economic information retrieval
# perhap bos
# outworn diagram
# signific the canadian
# congress machin registerband
# user services offered by medical school librari direct access systems
# von serendip
# dna 535
# use mad when
# information us unemploy
# data bas pot
# computer readable bibliographic data bas automatic new structure alert
# gotlieb dispos
# storehous wilson
# furnish kindr
# parenthesi core collection
# zeller alon
# harter molecul
# international labour offic impend
# serials distribution servic is automatic classification
# ross morpholog
# 169 fram
# microform information sourc secret
# richard d international seminars
# popular intact
# shawnee miss union book reserve
# carvil dormit
# markedli midst
# degre apathet
# step ineff
# lefev davenport
# ju educational needs
# cum spend
# johns hopkins university cent civ
# baker 462
# the community college librari new york public library
# western
# polytechn strictly
# logic usingrd
# thesaurus compilation method cataloguing experts
# 641 the languag
# motor 286
# experiment respons
# conven bould
# 2104 endless
# bibliographic record rough
# ultraminiatur vent
# italian parry repot
# general categories applic joan
# fishenden scrutinized
# ayr bell laboratories
# yale medical
# library
# part chemical information systems
# 598 que
# intraindividu british association
# lag alternative approaches
# ineffici perspect
# facsimil ballot
# 468 steep
# decision making system medical library association
# highli draw
# medical literatur sigm
# diagram benef
# the canadian dey
# nice 1038
# registerband revid
# serendip 778
# 535 mou
# when maron
# unemploy burd
# dispos sharpest
# automatic new structure alert wellcom
# econometric analysi fiab
# wilson boulder laboratories
# kindr bibliographical records
# driver 718
# option screen
# alon ent
# molecul deg
# impend molecular biology
# morpholog arnet
# secret bibliographic approach
# slater automatic construction
# externally available bibliographic data bas term values
# bowman back
# intact arbit
# the genealogical retriev bound
# critic solv
# grade epilepsy
# abstracts retrieval system
# midst serial cataloging problems
# apathet simkin
# computer index unsatisfy
# ineff besid
# davenport the dow chemical company
# spend choos
# 462 purdue library
# usingrd forward
# the languag 1915
# 286 cba
# scilken bak
# an investig claus
# sole automatic information
# respons veit
# linguistic theori arrang
# rough science
# information servic
# dictionary catalogu lent
# hirschman import
# parry repot the marc  format
# bibliometric descript w.d
# baumani unintentional duplication
# american psychological associ horton
# children sensit
# biographi moravcsik
# perspect henriet
# ballot penny
# steep supers
# draw adaptive information dissemination
# dey workmanlik
# thirti 88
# 1038 a.
# 778 imposit
# universal decimal classif boon
# maron classified catalogue
# sharpest transf
# wellcom 1969
# fiab craft
# scientific docu organic compounds
# chemical abstracts condensate
# evalu unique machine description
# 718 volunt
# screen cultural change
# mitteilungen fang
# allied
# health practition env
# creat k.p
# journal articles
# select themselv
# subject acquisit david
# bibliographic approach partit
# back automatic recognition
# mary l coh
# arbit 989
# bound stanley truelson
# solv du pont
# epilepsy
# abstracts retrieval system international
# conference
# simkin shelf
# besid household
# chemical information system 347
# information selected essay the other half
# choos halt
# forward index chemicus registry system
# 1915 devot
# alan sdc
# cba them
# claus perceived nee
# veit hesiod
# everi bibliomet
# prewitt thompson
# arrang abstrus
# human problem solv congress machine
# large academic research librari jan
# science
# information servic gestalt psychology
# mission led
# royal
# astronomical societi casset
# lent unlimit
# import faul
# the marc  format the ris
# w.d 227
# horton an operations research approach
# descriptor indiana university
# sensit 445
# moravcsik 1066
# workmanlik beng
# 88 some independent agreements
# ingeborg
# wint straightforward
# imposit 1053
# boon milieu
# 1969 ddc
# public servic connectivity matrix
# suddenli receiv
# manipul george washington university
# craft pattern
# mounting fiscal pressur isd
# insignific s.r
# volunt enorm
# endeavor skeleton
# memor mcan
# fang illumin
# k.p passm
# themselv national library
# fellowship photograph
# david southland industries
# partit general subject
# 989 metic
# stanley truelson working group
# prepar altsc
# du pont limbo
# shelf ackerman
# readable record first stage
# household desp
# 347 stem
# the other half many
# how do scientists meet their information ne 289
# halt melancho
# scrutini kas
# index chemicus registry system khursin
# devot main library
# sdc xhig
# them 152
# paper deacidif 935
# hesiod absolv
# thompson new factors
# computer literature search deacid
# crise 1370
# selbi arch
# territori scrap
# numerical method abov
# abstrus unselect
# physics journ head
# unlimit dimend
# led 23
# national
# book committe 765
# simplifi science information exchang
# fuzzif somerfield
# the ris obsolesc
# 227 landgraf
# an operations research approach aurelio peccei
# zipfian three academic
# libraries
# inquiri information crisis
# 445 disintegr
# 1066 1351
# beng access
# scientific discoveri weal
# straightforward film
# 1053 382
# milieu particip
# ddc keny
# connectivity matrix delinqu
# receiv 101
# pattern 958
# army technical librari the social function
# isd 1392
# work studi most
# s.r conservation library
# enorm pay
# skeleton expected search length
# illumin the human sid
# lowli cyert
# technical information index gesamtkatalog
# towards information retriev synonym
# photograph ident
# written technical inform flow
# public librari naznitsky
# general subject user requirements
# working group inverse relationship
# limbo pendergraft
# manual evaluation study
# decis 385
# descriptor information languag the foreign
# stem clump
# 289 1195
# guidanc country
# khursin 1033
# declens admin
# proce burn
# 152 copyright
# patent systems philosophy
# 935 obn
# elabor library associations
# 1370 biochemical journals
# its ambigu mathematical theory
# scrap fil
# abov integrated subject file
# unselect critical evaluation
# head aided subject
# tractabl data base
# polic joeckel
# 23 sect
# calgari coher
# 765 ston
# science information exchang unus
# somerfield anom
# obsolesc tis
# landgraf toward
# ellen californ
# elmer university system
# aurelio peccei prana
# custodianship rop
# disintegr wood
# 1351 indefinit
# recipi college library
# access 653
# arisen august
# film 1401
# 382 gerry
# particip accompany
# svalastoga book publishing
# crane rash
# special librari location analysis approach
# the scientific premis dat
# imper shosid
# delinqu prepunch
# 101 ulrich
# 958 221
# editori l.i
# 1392 stagn
# most os
# pay boch
# expected search length scor
# the human sid keywords using word
# cyert national network
# defer 1058
# gesamtkatalog o.a
# letter 423
# apparatu klempn
# compare retrieval using titl strikingly
# synonym convers
# ident destin
# flow w.r
# patricia standards for writing abstract
# cardiovascular serial literatur in table
# inverse relationship aw
# pendergraft library association library research committee
# finish ol
# preoccupi brief
# 385 1343
# the foreign threw
# clump cincinnati public
# 1195 801
# 1033 redund
# burn reconvert
# historical analysi agricultural division
# the information ne wat
# copyright awareness system using engineering index
# superfici political science
# integrated subject fil 1032
# the curriculum committe retrieval systems
# 	micrographic systems
# different user categori 419
# career suppl
# aided subject libbey
# bundi some implications
# joeckel state advisory
# council
# coher program retrieve
# unus heard
# advisory
# commiss dec
# toward correlative notation system
# architectural issu tool
# manuscript 726
# university system tang
# junior 1001
# prana nearest
# wood sight
# organic compound opello
# indefinit 65
# case studi pow
# 653 1008
# august twic
# 1401 quid
# scoring model air
# national bibliography entri graduate library school
# deacidif outstrip
# rash 1971
# location analysis approach 1447
# writer misunderstand
# shosid cost accounting
# prepunch w.g
# establish ot
# dilat combining title words
# ulrich was
# 221 obvy
# l.i foreseen
# new schem autobiograph
# obvious lambd
# os detm
# keywords using word bri
# national network numerical taxonomy
# 1058 yul
# o.a few
# 423 exhaust
# identifying desired work obstac
# t. primary publications
# convers large libraries
# destin stereoc
# klau 14
# w.r seldom
# standards for writing abstract combin
# contextu 1162
# katzer smre
# brief 727
# mathematical evalu 899
# 1343 delin
# threw recipy
# cleric sociomet
# 801 s.a
# liaison
# offic 524
# redund fals
# research network countway libr
# reconvert mink
# blake difficul
# awareness system using engineering index joseph
# roepcke
# 1032 three reports
# van rijsbergen druck
# usual new programme
# bibliotherapi launch
# 419 line cataloging system
# insuffici reward system
# suppl biological abstracts
# theori based information systems
# large information system the pebul report
# libbey cohort
# mary le 1265
# state advisory
# council leadermart
# heard ambigu
# dec international serials data system
# associ 1966
# correlative notation system 5013
# medical car c.t
# tool bridg
# 726 london graduate school
# nearest langlo
# 1001 federal library committee
# birmingham university librari metallurgy
# modern civil conjug
# sight technical information support activities
# olaf helm v.g
# opello cost
# evan 1275
# meaning world inventory
# 65 fus
# the teachable language comprehend word associations
# 1008 clap
# quid 1018
# roll a.d
# air guid
# graduate library school sail
# automatically generated weight preprint
# bonner intuit
# outstrip piercy
# worldwide censu minus two
# 1971 peac
# compact book storag 112
# library cost analysi turn
# 1447 l.c
# psychiatry librari bach
# misunderstand high
# w.g journals monitored
# university graduate depart 551
# abidjan albany
# foreseen 38
# neatli allay
# autobiograph fallout
# macquarri bramwel
# chained ring structur wait
# few african
# genesis
# polar oecd
# gilluli abridged index medicus
# intimaci star
# exhaust bandwagon
# conservat 142
# either 888
# suffici 822
# neighborhood evid
# intricaci bookbind
# 14 transit
# seldom econometric analysis
# lyle information
# centers
# 1162 ar
# smre 504
# combin 1148
# 727 library users
# estimating future demand level key
# 899 energy
# delin admir
# gener republ
# queue swanson
# s.a feel
# 524 1191
# theoretic interpret medical library
# fals 880
# mathematical basi 164
# justifi amalgam
# provis 499
# mistakenli accredit
# core
# sociological journ selective dissemination system
# launch quantitative fuzzy semantics
# line cataloging system 675
# reward system klet
# aided index 1224
# satisfactori anthropolog
# the evidence underli 810
# the pebul report pesonal author using derived search keys
# cohort uncontrol
# 1265 present developmental
# plagiar logical flow charts
# leadermart manual  service
# ambigu comprehend
# international serials data system batch
# norma the economic goal
# 1966 survey research center
# 5013 johnson
# c.t publications committee
# urban choosing physiology journals
# technological
# librari stangl
# bridg mun
# envisag integral part
# gerri mainstream
# london graduate school nin
# u. delph
# conjug unwieldy
# alphanumer blank
# v.g immun
# cost 1438
# 1275 byt
# information system develop decision theory view
# 1018 fellow
# a.d g.d.w
# guid artand
# preprint vorobev
# intuit ris
# minus two xerox
# peac enantiomet
# 112 hampstead laboratories
# turn sustain
# l.c handicap
# bach jerry
# broadu the current stat
# high ducket
# abstracts journ minicomput
# 551 uniform cataloguing
# rules
# presenc nonreview
# 38 973
# communication net 72
# fallout skept
# allay an informat
# bramwel sown
# medical literature borrow map
# wait bsi
# oecd embody
# free text word retriev the editor
# star 1112
# bandwagon got
# andries
# ric fem
# feeder 522
# 142 1151
# defense documentation cent nonstandard
# 888 del
# 822 1376
# evid em
# bookbind magnetic tapes storage
# transit 583
# onc scientific
# information
# traffic v.v
# negotiated search facil replac
# lexical ind army
# deeper structural diagram generation
# 504 current
# abstracts
# 1148 schematic
# pharmaceutical librari saw
# preprocessor purchas
# key whos
# forese 18
# pure medical library assistance act
# admir jeffrey
# interlibrary loan policies directori 1877
# swanson nan
# tomita
# feel british bibliography
# 1191 preliminary repot
# deceler pomona college
# 880 undergo
# 164 1067
# judgement latin
# amalgam ii
# 499 possess
# negentropi general statistical model
# accredit 544
# selective dissemination system the multiterm index
# 675 j.e
# unnecessarili the citation identifier
# 1224 1937
# era febru
# 810 1324
# kruskal medico
# uncontrol topolog
# anthropolog aitchison
# comprehend its history
# batch fear
# johnson 148
# griffith 850
# stangl referee system
# dessauer citation relationship indicators
# integral part 703
# axiomatic relevance tolerance theori lynch
# blank doe
# immun comparison
# mainstream chapt
# these 1411
# forgotten their relation
# 1438 adult reference service
# decision theory view undertook
# fellow 1919
# g.d.w new york state
# vorobev ford foundation
# tangenti bord
# processing bind ubiquit
# raisonn simply
# xerox excurs
# sustain wessel
# handicap n.l
# augment dorm
# fascicul ger
# minicomput ampersand
# nonreview 1126
# 973 134
# 72 statistical approach
# preposter 1326
# performance measur 1047
# articulated subject index reproduc
# sown library planning
# ellsworth the rol
# bsi hing
# huffman 773
# map dazzl
# the editor library procedures
# astonish katz
# 1112 stack
# got swets model
# 522 contempl
# 1151 reloc
# nonstandard land
# 1376 the scholar
# data handl met
# 583 kolb
# v.v nationwide library program
# final report
# replac hoc
# antiqu evaluating information retrieval systems
# belief linguistic hedges
# saw schneider
# purchas their
# same aggress
# 18 redundancy codes
# exploratori janu
# medical library assistance act distast
# the ne 602
# jeffrey 1947
# 1877 kent
# explicitli colorado academic libraries book processing center
# systems consult 189
# hole some correlates
# geniu naz
# nan
# tomita forc
# preliminary repot focuss
# undergo electron
# 1067 american institute
# latin automatic keyword indexing
# part
# ii sodom
# concis bely
# graphing speci adumbr
# environment summary review
# biological
# abstract systems development corporation
# possess c.w
# general statistical model imb
# herschman other new techniques
# 544 biosciences information service
# the multiterm index fascin
# clearer administrative effectiveness
# j.e electronics
# engineer
# 1937 counsel
# equal missil
# realism f.n
# 1324 ralph
# medico adject
# topolog spyersd
# aitchison mechanical indexing
# fear telephon
# feldblyum 1305
# 148 gilcr
# manufactur assess
# the first two year resuscit
# aris nineteen information scientists
# evaluating
# information retrieval systems
# treatis month
# 850 classification catalogue code
# referee system 427
# 703 library process
# single comput is journal publication obsolescent
# lynch d.e
# doe dc
# comparison the history
# 1411 dwel
# undertook yast
# 1919 1198
# consider crosscur
# annan the journal
# ubiquit 145
# cataloging expert tradit
# excurs bir
# elus north americans
# syllabu kronick
# the price gilbert memorial librari pushdown
# effective hierarchical information system science
# museum library
# intellectual influ the directives
# wessel disciplin
# jealou u.k
# n.l tied
# poorli subject area through bibliometric analysis
# institution profit
# ampersand an information retrieval language
# dove gul
# 1126 375
# 134 nas
# statistical approach american chemical
# society
# 1326 relative significanc
# 1047 simsov
# american library
# associ slog
# western
# reserve univers 1137
# reproduc substruct
# the rol vaupel
# business office procedur diastereomet
# 773 an assessment
# hing engineering literature
# oblivion kenneth john
# dazzl rapid structure searches
# suspicion saf
# katz the recording
# stack automation
# task force
# the viabl subgroup
# swets model funny
# contempl the title catalog
# harvard univers m.f
# reloc tip
# relative signific international  cooperation
# land n.d
# periodical literatur machine form
# the scholar interactive retrieval
# met landau
# kolb project
# th  program
# nationwide library program
# final report information processing societies
# hoc the world
# business studi checkl
# node get
# specialist jardin
# schneider particul
# their weingot
# aggress performing evaluation studies
# creatur dagnes
# distast woost
# 602 computer systems
# 1947 a.i
# member absorb
# kent 480
# american chemical societi 515
# least effort
# an introduct cost model
# pay librari cataloging experts
# enantiometr hyd
# 189 counterpart
# forc prompt
# focuss some limits
# documentari defense documentation center
# electron intraindivid
# automatic keyword indexing
# part 1022
# sodom 483
# working task forc in november
# hall emerg
# r. plato
# current cont restart
# adumbr coach
# summary review reliable communication
# dissimilar trust
# go samet
# c.w plu
# fascin 1104
# counsel rand
# introductory lectur paul
# missil thorough
# f.n 997
# ralph euphor
# adject three university libraries
# organic chemistri zaremb
# telephon emin
# 1305 manufact
# massiv retrieval features
# assess 402
# hyde 1314
# henc of
# resuscit troublesom
# drugdoc thesauru the documentation
# month inge berg
# 427 182
# library process divid
# interview guid 1959
# idealist unexamin
# d.e en
# dc screened
# yast immens
# dispar relevance disagreements
# 1198 paradox
# department behavioral approach
# 145 field
# tradit peak
# santa monica bliss
# kronick cooperation between types
# imperfectli r.m
# bivan 1907
# plate randilph
# pushdown occur
# relative effect 1309
# disciplin 607
# u.k mov
# represent profess
# biological act sought
# viniti donohu
# profit nonrelev
# text structure complex instinct
# vector medy
# 375 nonacadem
# bayesian tol
# formerli park
# 1137 psychological abstracts
# its advantag margaritov
# unaccept promot
# vaupel grammatical elements
# formal languag bibliographic tools
# kenneth john touch
# operating experi commercial
# on
# recognis career contingencies
# godunova 650
# subgroup master tapes
# corpor horizon
# eventu murdock
# the title catalog 1362
# m.f like emerson
# tip library catalog
# unrecogniz identifying significant research
# n.d the  automatic document retrieval system
# rage manpow
# machine form 1316
# landau v.c
# project
# th  program on information needs
# explan formal system
# applied
# technolog computer evaluation
# the world service based
# between typ nons
# deliv 1410
# get superst
# pesonal author using derived search key 1132
# consensu wasserm
# jardin chemists read
# dead languag capit
# search manu c.k
# dagnes 3
# education information sci minsky
# actual scholars
# a.i british steel corporation
# 480 mous
# 515 minisc
# dgamer condit
# cost model selected lists
# counterpart being
# tall spur
# prompt vil
# scientific inform gennaro
# coach collab
# 1022 emerson
# 483 mechanized chemical
# plato isenho
# emerg tax
# restart affect
# unexplor doing
# samet enterpr
# plu house us
# 1104 time loan system
# rand comparative assessment
# indexing term subaspect
# paul union library catalogs
# thorough misstep
# national academi policy
# 997 92
# rothman qua
# unexpectedli homog
# pretti b.n
# fuzzy ord degrad
# apprais 33
# zaremb simil
# emin biomedical communications
# ranganathan par
# 402 subject indexes
# 1314 333
# of bin
# troublesom primary journals
# inge berg propens
# royal society scientific information confer 651
# 182 f.w
# three academic
# librari frank
# 1959 brody
# secondli line systems
# divid incred
# unexamin calderon
# choic scientific
# communication
# some factors affect howard
# immens interuniversity communications council
# paradox pz3
# behavioral approach special librarianship
# field plain
# peak 398
# bliss central serial record
# r.m design equations
# 1907 thiel
# randilph index term weighting
# occur insep
# positiv ph
# coding organic compound doorway
# 1309 g.g
# 607 1085
# mastermann dorfman
# profess interactive bibliographic search
# some structural characterist subject analysis
# indexing language structur monsanto company
# sought library
# systems
# donohu physical sciences
# nonrelev goldf
# instinct 203
# attitudes toward academic library reference servic simulation program
# nonacadem eas
# park scientific literature
# slightli prem
# margaritov j.h
# keynesian 940
# promot the
# american scholar
# risen christian
# touch alik
# commercial
# on 1102
# nontrivi 1416
# 650 information flow systems
# horizon construct
# murdock news service
# 1362 cli
# formal investig vot
# like emerson pref
# informat recent growth
# obviou fiv
# structural diagram gener alexandr
# library catalog pick
# eastern europ appertain
# identifying significant research black
# the  automatic document retrieval system the notion
# pierci guyton
# task forc 1144
# current physics
# titl expendit
# manpow systematically abbreviating english words
# 1316 1930
# humanist 1241
# v.c science communications
# formal system phd
# brann miny
# computers rev faceted classification
# 1410 in
# ranganath
# factual protect
# strikingli appendix
# 1132 threaten
# colorado academic libraries book processing cent output
# computer
# manipul cryptarithmet
# chemists read piec
# capit u.s.a
# c.k impract
# portion about
# 3 in part
# small hospital librari twofold
# ladder caisf
# d. 1967
# insecur bibliographic analysis
# mous 308
# condit spiro
# legal restrict rml
# restorationist naiv
# spur s.j
# gennaro undon
# emerson the weapons acquisitition process
# clarifi 331
# tax publ
# world inventori 78
# affect hierarchic clustering
# house us resourc
# time loan system management techniques
# inaugur leonard
# subaspect 108
# dynamic current l
# thirteenth archives infrastructure
# misstep 722
# 92 thesaurofacet
# lectur scientific research
# qua crimin
# b.n property
# veilett acquisit
# degrad c.l
# 33 meas
# 333 ext
# propens pav
# 651 controvers
# f.w writ
# frank standard reference
# code
# incred branch
# departur ben
# calderon money
# beneficiari confound
# higher textbook
# howard rothm
# interuniversity communications council revesz
# pz3 loan
# special librarianship lou
# plain r.w
# 398 kruza
# central serial record 1292
# thiel 919
# ph reconciling thesauri
# cover
# voluntari h.b
# g.g kapl
# 1085 thes
# gave complete boolean
# interactive bibliographic search incorrect
# doorway c.j
# fasana weech
# 203 r.a
# simulation program resort
# sensibl bromid
# chapters f nonbibliograph
# all 918
# appreci hyph
# the computer search cent vend
# connected curricul
# eas sokolov
# hyatt hous mutual exclusivity
# system sci 290
# j.h apply
# frighten bath university library
# uneasi relevance
# judgements
# 940 nameless
# the
# american scholar 1068
# user br eldr
# christian monteith college library experiment
# alik automatic subject citation
# alert
# 1102 assimil
# 1416 225
# coler petit
# further scheffler
# fraudul staff
# construct lib
# realist decad
# duboi 304
# crosscurr an inquiry
# phrenolog imagin
# recent growth 1277
# nonorgan systems requirement
# pick 986
# appertain national survey employing standardized tests
# farradan rid
# black oclc
# guyton 1386
# 1144 pion
# 1930 untrammel
# 1241 275
# phd schless
# charles ammi cutt vuln
# conjectur euratom thesaurus
# oliv freedom
# understanding
# natural languag saskatchew
# chanc 1952
# protect 867
# a.a 1366
# appendix context indexing system
# threaten heavily used biomedical journals
# output donaldson
# cryptarithmet scientific documents
# piec 107
# automation stops her hampshir
# the territorial imp 077
# u.s.a c.f
# impract bioreseach
# justic microfiche catalog
# about semantic text analysis
# in part gardin
# twofold ohio college library center
# caisf the testing
# 1967 uncomfort
# electrical engin pag
# determining relev logarithm
# 308 richest
# incept title derivative indexing techniques
# randomli the academic library essays
# rml cram
# naiv sgal
# s.j weapons acquisition
# undon gallagh
# spiro magnet
# the weapons acquisitition process she
# comparabilti 384
# perfor general categories applicable
# fuzzi davison
# 331 monolith
# selective dissemin phrasing
# 78 bristol
# resourc 769
# uoi hawai
# case western reserve univers brandhorst
# centre n dust
# leonard 741
# 108 chauveint
# 722 1062
# thesaurofacet millimet
# scientific research wear
# crimin neurological diseases
# acquisit 1375
# martha nelepet
# the lister hill national cent undersc
# c.l bookstein
# the gatekeep coordinate index word list
# the document mathem
# new hampshir georgia text search
# system
# annum library system
# branch geur
# alli professors ben
# ben preassign
# money the psychologic criteria
# confound market
# textbook 1210
# the medical library associ m.i.t
# reactiv 67
# vacanc distress
# revesz along
# loan indexing language structure
# cost analysi 274
# wyatt chen
# r.w 795
# kruza 1154
# personnel util new england research application center
# economic effici g.d.m
# 1292 computer searching
# 919 thrive
# h.b 771
# decision analysi 587
# politi chemical structure searching
# complete boolean intertemp
# incorrect academic libraries
# violenc rochard
# panini afflu
# c.j avenu
# weech american librarianship
# cranfield aeronaut metropolit
# r.a rework
# genesi index production
# resort proton
# bromid od
# nonbibliograph van rijsberg
# 918 barc
# complex polycyclic structur black box
# alic supervisory staff
# semantic text analysi pip
# neighbour r.p
# effectiveness analysi library resources
# theoretical linguist 1183
# multimillion providing bibliograhic services from machine
# sokolov downward
# advisori technological
# library
# fall changing metropolis
# steven south
# asia
# its operating effici 1139
# 290 lieberm
# attent adorno
# nameless judg
# spicer 410
# sloan scientific discovery
# 1068 from november
# eldr truck
# considering quantitative measur coding organic compounds
# automatic subject citation
# alert pertin
# assimil mit
# tribal computer handling
# curricula technical
# periodicals
# 225 fillm
# cost benefit analysi mullin
# scheffler michig
# staff dk
# petit cauty
# lib cetron
# decad barry
# its appl 1174
# 304 line information retrieval systems
# abil 874
# imagin epidemiolog
# 1277 the club
# guarante ms
# freeli 674
# bierman subst
# 986 superf
# oclc bit
# 1386 1450
# theoretical semant retail
# dissent man
# untrammel operating experience
# 275 idiosyncr
# schless scant
# scientific technical inform equ
# freedom operational ballots
# nonprofession promulg
# 1952 soviet socialist
# republics
# 867 sho
# 1366 sphere
# ursul rasmuss
# servic level
# syracuse univers library benefits
# shell
# research limit right
# context indexing system esot
# organizing library collect masterman
# donaldson diffus
# lightli practical guide
# crucial thesaurus control
# serial literature us 336
# 107 1016
# hampshir graduate education
# climat interactive reference retrieval
# champion d.h
# 077 thomass
# c.f information center administrat
# bioreseach chronologically
# updat general description
# advise stimul
# microfiche catalog liaison
# fewer envid
# gardin nhi
# invari the phenomena
# browser 1918
# predat num
# uncomfort a.w
# logarithm teletyp
# richest retrieval systems
# validli coat
# comparative effect epd
# cram sociological research
# magnet program design
# gallagh ass
# energi manip
# veteran herein
# she 437
# nobel laur scientific disciplines
# 384 column
# sterling memorial librari least cost decision rules
# state social dimension
# davison 689
# retrieval systems
# 	micrographic system chemical
# information
# happi goodwil
# monolith different categories
# bristol law libraries directory
# 769 compass
# brandhorst w.h
# ventur i.m
# chafe staff participation
# citi 1408
# franc samuel
# dust cur
# 741 decimal
# classification
# directori bibliothequ
# illustrative computer program vagu
# 1062 on informal processes
# millimet across
# neighborhood information cent chemical research
# wear pay libraries
# 1375 s.p
# nelepet social science research
# bookstein inescap
# coordinate index word list verit
# georgia text search
# system gilchr
# information valu 626
# library system american overseas library technical assistance
# geur library interface
# scholarli styl
# rome on improving communicat
# professors ben 783
# preassign uniterm
# the psychologic criteria hdb
# market n.n
# downstate medical center librari bewild
# 1210 2267
# m.i.t a.h
# 67 circumst
# distress reynold
# along footnot
# vocabulary build cogn
# providing bibliograhic services from machin 35
# nyquist referral centerss
#         consulting
# 274 user needs
# chen an algorithm
# 795 subject specialists
# 1154 158
# zipf distribut acknowledg
# mavi library association
# microphotographi manpower problem
# former radable data bases
# trifluoromethylphen national systems
# olsen 503
# comparis some experiments
# g.d.m american library
# school
# thrive the application
# 771 marth
# 587 gilbert
# radic generic medium designations
# thesauru graph model
# rochard 840
# avenu cut
# american librarianship network
# rework milwauk
# proton attitude survey
# standardized inventori 529
# new england regional medical library servic query expansion
# black box interim
# supervisory staff document analysis
# saskatchewan apt
# r.p gillu
# tanzania bibliographical statistics
# 1183 cpm
# downward 565
# the administr newm
# south
# asia library decision making
# 1139 an indirect method
# adorno chemical technology
# are titl research program
# judg tract
# 410 established
# order
# grammat the impact
# vari development laboratories
# truck zyabrev
# pertin automated retrieval
# novel philosophi discrep
# mit 436
# cuadra coherent social groups
# nonrandomli farrel
# utopian frontlog
# newman the genealogical retrieval
# mullin ideolog
# langendoen preh
# dk he
# primary journ canadian national science library
# cetron singleton
# the effici record
# 1174 formid
# 874 port
# chiefli 1288
# epidemiolog pass
# the club technical libraries
# comparative search util
# serial cataloging problem engineering societies library
# ms cler
# save weeding library collections
# 674 barb
# bit bierm
# retail effect
# 1450 700
# man apparat
# probabilist serial publications
# quantum w.a
# scant leng
# document delivery cap silv
# promulg cultural approach
# zholkovskii convint
# easier 1460
# disclosur based scientific search services
# serial massonneau
# sphere 1129
# level 552
# prosper nonlead
# right the management review
# utility contour chin
# dispassion american library associat
# diffus surv
# thesaurus control c.m
# 336 requisit
# 1016 automatic abstracting
# d.h 285
# in industri salt
# neither relational indexing
# hive ut
# stimul michael
# liaison translit
# nhi maruyam
# engineering literatur from occupation
# the phenomena spawn
# honor micropubl
# 1918 britain
# a.w includ
# teletyp ukr
# coat 2
# evaluating technical library effect town
# epd vocabulary control
# sociological research h.a
# program design 1077
# future develop lieu
# herein advice bureau
# 437 the status
# lisa documentation
# empirical hyperbolic distributions
# column unt
# the information dissemination cent mandelbrot
# 689 vledut
# goodwil bnb
# franci automated alternatives
# prove scientific discipline
# metallurgical publ thos
# compass compens
# w.h the junior college library
# codifi 1383
# i.m 1920
# 1408 aruntunov
# samuel 1975
# multilater dispers
# bibliothequ library participation
# helen young publishers
# vagu just
# across 242
# automatic extract schatz
# heavili christ
# chemical research inaug
# s.p general systems research
# librari scientific theory
# social science research book selection
# sympathi impos
# verit depress
# inescap sometim
# subject list 1403
# interstiti mls
# inequ accadem
# countri tid
# from novemb educ
# para expedit
# 626 mnemon
# protein crystallographi n.h
# lyman dispert
# 783 mack
# uniterm singl
# hdb 1463
# n.n might
# anomi information technology divij
# 2267 middl
# a.h rigid
# bewild mary ellen
# circumst practical man
# meticul corrupt
# reynold index term frequency
# some
# preliminary result 804
# footnot bark
# 35 overcam
# spectacl quick
# an algorithm hans
# 158 berg
# acknowledg western michigan university
# versu nevel
# manpower problem korolev
# linguist staunch
# seventi metropolitan library
# 503 e.m
# enabl commerc
# moder lot
# american library
# school moon
# liter fletch
# penri invis
# library systems analysis guidelin new centralized acquisitions
# minker hamp
# compar industry users conference
# in
# ranganathan unint
# panizzi uniform federal report numbering
# system
# gilbert standard costing
# graph model 532
# 840 151
# somewher two paradigms
# unequival smart
# cut civil
# the wiswess counterexampl
# influenc its ambiguity
# equilibrium m.n
# network milam
# technique develop the law
# attitude survey filing systems
# 529 scientific journals
# interim 186
# endeavour fisc
# apt drown
# biological abstract psychiatry libr
# national librari 606
# chemical docu speech
# weswesser line not hagstrom
# cpm 316
# probabilistic index cornell university
# 565 informatolog
# supervis inexpery
# monetari whereby
# piotrovskii encount
# an indirect method lorsch
# kochen bed
# research program industrial research environment
# tract took
# the impact cliff
# zyabrev the national science library
# united
# st 807
# discrep the automatic encoding
# diametr comply
# 436 amb
# farrel sketchy
# frontlog breath
# ideolog communication patterns
# permuted chemical
# line not pattern recognit
# he survey books
# molecular biolog wast
# singleton uninterrupt
# record standardized inventories
# formid southampton public libraries
# united states
# librari 359
# 1288 352
# pass cris
# engineering term illinois library association
# util 454
# certif answering system
# fortran kuhn
# effect 895
# 700 national commission
# w.a baum
# evolutionari plotnick
# line servic marvin
# catalog bas idiom
# international med the new librarianship
# euphoria found
# altmann cartridg
# cultural approach correct
# 1460 palo alto
# massonneau octob
# beeler 1010
# 1129 the influenc
# 552 homolog
# nonlead vers
# the management review involv
# the record the information uses
# legal literatur 351
# innumer modern systems research
# willi 507
# c.m worthwhil
# requisit orthodox
# casual garfield
# 285 small medical libraries
# american
#   psychological associ renown
# salt postgraduate medical institut
# paper comparative searching
# michael iit
# large mechan user assessment
# grosser 1064
# c. remaind
# spawn mackay
# age 953
# britain hom
# includ heaviest
# lingual annot
# warrant matth
# 2 1178
# town based system
# vocabulary control 1202
# scientific specialti the crisis
# older international standard
# bibliographic description
# h.a simon
# 1077 the  cataloging
# secretariat
# lieu urban development
# doctor experimental on
# advice bureau 458
# inter pilot
# journal usage pattern human problem solving
# mandelbrot j.s
# vledut unfil
# bnb third annual northeastern
# compens an
# international conference
# feldmann p.l.k
# prose paleograph
# constant carp
# 1383 bowl
# 1920 zad
# analytical rel lub
# allied field funda
# aruntunov hamadryas baboon
# 1975 hum
# dispers data collection
# ackermann on aggresj
# cumul virtu
# onli leipzig
# just 1048
# classification schem structures
# public library
# inquiri ten
# uniformli leas
# federal ministri smal
# aspect abstract szpilrajn
# 242 relative effectiveness
# schatz dil
# nugent intraspec
# citation analysi textual correlates
# cipher dittm
# christ 1045
# academic environ 998
# general systems research unprov
# impos 157
# information retrieval learn subscrib
# depress herschm
# matching chemical structur tenet
# compound word 623
# sometim experimental information service
# 1403 ahead
# incompar research parks
# educ rain
# expedit lyapunov
# mnemon chemical papers becoming more informative
# n.h tape arrival dates
# dispert comp
# rossler 1290
# singl folg
# 1463 brutch
# might current awareness publications
# middl on
# rigid kind
# mary ellen cost benefit analysis
# corrupt myer
# organization information transf 930
# wonder remedy
# overcam 738
# 804 photocompos
# quick harwel
# campus library document delivery servic metamorphos
# nevel wert
# firstli psychological
# journal network
# aslib research depart seat
# korolev unenvy
# staunch w.l
# e.m technical periodicals
# lot 655
# moon intend
# induct secure
#  constructive chang
# invis inaccess
# participating librari intract
# uniform federal report numbering
# system formal analogues
# 532 837
# practical manu call numbers
# 151 official catalog
# occupi burkhalt
# smart ir
# civil g.k
# counterexampl southampton university
# m.n assault
# stimuli the publication inflation
# slowli the hypothesis
# milam stretch
# the law unattract
# 186 1866
# internship thank
# centralized process an approach
# kurth rmp
# drown mason
# 606 computer search center statistics
# speech 793
# hagstrom the library
# 316 ohm
# informatolog approval plans
# encount cat
# the journ british national bibliography
# card service
# lorsch american library association pre
# bed ultraminy
# clare 704
# cp levy
# translat boat race
# its rol 659
# verif hunts
# took 502
# cliff 1078
# 807 mol
# unproven 447
# processing inform chapter nine
# breath bureau
# reiter chemical registry system
# archivist 968
# struggl lik
# recreat some
# preliminary results
# pattern recognit 628
# graduate educ borrow
# wast mclure
# uninterrupt ardrey
# detriment ged
# companion blanket
# 359 leigh
# special library period a.b
# index chemicu international standard serial number
# 352 695049
# an estim document data bases
# revolutionari exag
# planning memorandum numb addit
# third dimens nonmetric
# hypothesis
# book avail cannot
# 454 effective hierarchical information systems
# stack thin maryan
# answering system f.a
# kuhn n.l.l
# steadili rudolf kaiser
# 895 system development corporation
# tortuou reinv
# engineering societies librari biomedical engineering
# plotnick adjust
# marvin 1337
# idiom 413
# packag fring
# statistical interpret mot
# the new librarianship the planning
# found tech
# parentag bolef
# cartridg 388
# the descript nuclear age
# correct 780
# technical information support act rom
# palo alto 528
# they ask quest 752
# octob techinical bibliographies
# 1010 381
# chemical papers becoming more inform readable form
# homolog vary
# involv sourc
# 351 popul
# modern systems research 644
# 507 chronicle
# worthwhil specialists training problem
# experimental comput robert
# orthodox the information dissemination center
# abstract journ loft
# garfield recont
# renown foreword
# postgraduate medical institut jr
# kasparova 426
# iit predecess
# bimonthli pitfal
# 1064 201
# remaind trac
# mackay judicy
# 953 counteract
# leningrad krupskaya institut populac
# prescript trifluoromethylph
# author catalogu the aberrystwyth index languages test
# heaviest poisson
# library science literatur berkhof
# annot william
# 1178 1379
# chomski mesh
# copenhagen 377
# based system e.t
# 1202 data
# bases
# simon 1269
# the  cataloging
# secretariat satellit
# experimental on engineering index
# 458 calend
# pilot sked
# rule whilst
# chicago librari wiiliam
# ford found standard distribution format
# unfil 244
# loyalti conclud
# third annual northeastern 1233
# p.l.k how
# paleograph encompass
# butler prepond
# judith bibliographic coupling  extended
# data characterist scientific knowledge
# bowl yat
# deriving term rel an allocation formula derived
# indiana univers 1372
# hamadryas baboon poverty
# virtu indirect
# horner multidimend
# slamecka wiegendruck
# leipzig 1217
# 1048 vickery
# ten 389
# leas fasan
# army corp 7090
# szpilrajn information flows
# holism wov
# linguistic hedg barbar
# core nursing librari year specialist programs
# 1045 178
# pattern classif kindest
# quantif hit
# color negentrop
# 998 af
# 157 79
# subscrib the cas
# tenet r&d
# prudenc the terminology
# 623 g.b.f
# mysteri groups
# employing free language
# ahead unfamili
# rain operational research
# stone proc
# lyapunov scen
# document writ reprint
# idiosyncraci red
# 1290 american study
# pragmatic aspect root
# on frequency analysis
# kind computer programming
# myer carbocyc
# generalist viz
# 930 unsolv
# 738 maintain
# photocompos neg
# harwel lubr
# wert body
# disguis etz
# knapp threshold
# corollari reach
# organizations
# productive clim assisted approach
# spuriou plenty
# psychological
# journal network 1096
# seat dear
# unawar professor
# ziman
# other characterist heteropa
# w.l loss
# ideal spee
# devor medical literature analysis
# 655 empir
# technical articl the hidden dimension
# formal analogu depl
# secure
#  constructive chang neat
# intend historiograph
# kegan 362
# inaccess 1007
# intract 76
# procur displac
# some econom retrieval system based
# 837 renata
# kilgour
# oxen chemical notation
# official catalog current problems
# burkhalt mounting fiscal pressures
# ir converting systematic names
# g.k information system development
# assault rand tablet
# algebraic system national
# science library
# stretch 154
# factors determin six new
# england state universities
# 1866 955
# thank project selection
# unattract dav
# byte net
# an approach standards setting project
# dorothy gross 974
# rmp paulin
# mason contemp
# 793 s.l
# ohm wertheim
# scientific revolut kountz
# 704 hin
# 659 1110
# qualifiedli index bibliographic
# 502 bran
# 1078 minim
# temporarili mary lou
# ...
# james
# treu superb
# linguistic descript alloc
# barhillel georg
# irrespons sequ
# referativnyi zhurn been
# busi flen
# hess any
# physics abstract 1027
# 893 neglig
# the structur allegy
# job dimens unaw
# crt the outlook
# queer text data base
# polycycl urg
# disciplinari 1034
# the growth stressed
# east africa lov
# berkeley bowker company
# phage the acquisition
# thesauri persist
# origin 472
# sway effort
# reliable commun 1201
# customized user servic science literature
# through inclusion
# 713 878
# statistical bibliographi ct
# b.k 1270
# answerback 868
# 633 wynneedward
# invit west
# african
# university library build hym
# 859 law libraries
# scale
# social sciences information system drast
# ought overdu
# cowel backlog
# data retrieval system schemes
# ba using commercially available literature tapes
# international standard
# bibliographic descript fact
# term weight state system
# planning organ overnight
# if academic environment
# encod practic
# drucker med
# 1980 services
#         network
# 505 lipset
# than markuson
# seventeenth 869
# shepard in may
# subtitl should
# linda hall librari dewey decimal classification
# 1268 1300
# retrieval tests
# part 1240
# militari american federat
# yakubovich library response
# chernaya mar
# subject catalogues
# head cataloging rules
# regional medical library
# program e.l
# epidemic theory an appl multipurpose retrieval language tool
# citation index s.e
# equat versatil
# m.e title compression code access
# bureaucraci classification
# etzion schofield
# farmer president roosevelt
# 181 the management
# penni terminolog
# paramount compress
# invent storeh
# nicholson alphanum
# exercis 440
# s.b phrenology
# hierarchically
# structur reply
# 1091 750
# inbreed 671
# engend linguistic description
# mikhailov compression word coding techniques
# result rac
# rewrit periodical resources
# trilog chemical abstracts condensates
# 789 marguerit
# jean pric
# norm engineering company
# instanc indexing coverage
# its characterist 757
# continuum perfect
# decipher lin
# solac successful information
# wors use data
# rest poss
# largest conf
# automated library system taub
# one sent
# commonplac dewey
# social action program filing catalog cards
# analys peck
# computerized information retrieval servic computerized retrieval
# system
# inspect computerized drug information
# suffic 481
# architect syllab
# 200 based chemical information services
# 1203 haas company
# houghton moo
# arous new hampshire
# privaci line services
# physiolog i.a
# decid satisfy
# symbol second international seminar
# authorit conject
# c.r user charges
# give 267
# technological societi hundr
# serials project hippy
# rossit beckm
# skew distribution funct carnot
# applied geophys anyon
# montagn al
# mid seeking behavior
# management science
# model n.e
# cc pat
# numbers gam east
# detailed subject retriev the implementation
# worldwid 197
# aslib workbook
# worri discontinu
# irwin sampling errors
# treati trib
# refere library science literature
# born matthew effect
# declension wolt
# introspection prevail
# tlc new general classification
# marqui lol
# analysis purpos searching  condensates on
# tauber big science
# solovyev symbolic nature
# niblett axiom
# differenti 1457
# requir graduate school
# centr serv
# health scienc uncorrupt
# remuner kozumplik
# 523 decod
# previou indexing systems
# deliveri phyl
# jigsaw national hospital panel survey
# on relev dym
# parget charles university
# bibliographic coupling  extend mult
# 508 neurolog
# expos bury
# 894 modern organizations
# barker allow
# embed conduc
# 1280 flex
# languag develop
# kraft corol
# new techniqu destroy
# substanc alexandria
# solution
# pro 1167
# burton analysis purpose
# manchester business school phas
# gushe provint
# scientific commun bom
# technical information facil coverage overlap
# realkatalog welsh
# triumph red cross
# 1454 spald
# fulfil polytechn
# verner project intrex
# d.u nont
# opinion 80
# comparative index downstate medical center library
# adam secondary journal citation
# 246 dewey decimal classifications
# 1895 dialog
# activist 482
# d.m periodical sources
# apart gardn
# bia savann
# 861 281
# nonfict the ring index
# some preliminary consider t.l
# 819 herbert
# nickelsen
# copiou sir karl
# ree 578
# signpost essay
# bradfod epistemolog
# 1354 the workshop
# vindic oldrich
# door 1302
# subclass gros
# f.e microtext
# dash 1421
# faci univers
# reference book 479
# nonscienc joint center
# computer fil worry
# real group meeting
# woven reasonable application
# dorr 1003
# inquir tiny
# collection overlap citation indexes
# veedut wyndham hulme
# inspir 860
# ansi citation counting
# inextric underdevelop
# herzberg 799
# 913 anderl
# parkin 851
# chih ethn
# easiest shawnee mission
# nonseri terry
# books used within clay
# literature
# fil automatisierte information retrieval dienst
# 1331 scrambled
# computerized library catalog fil unsuccess
# danton ecological correlations
# 617 industrial social
# psychology
# general index languag informal communication among scientists
# standera rel
# group permut
# 631 the reporter
# information
# which bodley
# janic 266
# 665 whel
# historian benefit
# flavor rothstein
# wa information retrieval organizat
# k.w modern civilizat
# southampton
# univers bailiwick
# say w.w
# 1207 is
# w.b m.l
# carrol retain
# 580 ilo
# consequ miss esther
# 61 randal
# 734 mountain
# titles index 938
# assess us distinct
# function procr
# forenoon the description
# english disburs
# chapter nin cost survey
# community systems found 1418
# loll miles
# smith
# inhibit county
# s.m pretest
# partli april
# disjoint botany
# 323 quantit
# nonprofit control techniques
# cardiovascular instruct
# 1400 fold
# decentr brain
# 882 unpredict
# defense
# documentation cent automated information
# weil 928
# wisconsin bath
# 912 braun
# manfr sperling
# salko
# 1423
# medical commun
# rigor
# entitl
# confus
# modern american
# pulsif
# 433
# beli
# maryann
# computerized bibliographic system
# large biomedical library
# part
# sampling error
# chemical structur
# d.r
# martyn
# leader
# action social science bas
# california
# library expenditur
# 330
# chemical
# inform
# certain
# rowen
# 612
# heap
# typewrit
# 957
# index term
# significant word
# 999
# stage
# els
# yovit
# 126
# grema
# annual review
# merit
# biomedical research librari
# extramur
# nanci
# computer handl
# interactive system
# lenor
# still
# 349
# laszlo
# fund
# 119
# pharmacolog
# sussex
# turmoil
# 747
# suffer
# the futur
# inform
# w.e
# soft
# vest
# carol
# waligorski
# yale university
# librari
# microcard
# 613
# harcourt
# neglect
# miln
# cognit
# invers
# overwhelm
# the wilcoxen test
# american societi
# 98
# environment managing differenti
# item
# pragmat
# wisdom
# analysis program
# most british
# derec
# information retrieval situ
# million
# gwendolyn
# depriv
# 442
# g.f
# academic library collect
# deplor
# to
# the great gas bubble prick
# ddt
# latin america
# 608
# plant
# foci
# wheeler
# closur
# chronicl
# 690
# intellect
# wet
# media
# documentation
# empirical hyperbolic distribut
# complement
# alien
# paramed
# becaus
# index bibliograph
# neck
# belver
# 1145
# kaltwass
# vener
# 240
# some independent agr
# columbia
# c.p
# 825
# henderson
# valu
# name ord
# mathematical theori
# project select
# assign
# trueswel
# 1340
# bibliographic support
# hard
# recon
# ratio
# imprecis
# promis
# 160
# 372
# j.f.b
# churchman
# evaluation studi
# overlap among
# interactive search
# reproduct
# atmospher
# 117
# belton
# 071
# gedrimovich
# craig
# invest
# anyway
# usabl
# 1944
# anabl
# 309
# tone
# exponenti
# ophthalmic literatur
# practical guid
# 764
# d.b
# butterwick
# managerial cost account
# medical librarian
# 170
# 1385
# 084
# the council
# nor
# came
# protract
# luhan
# relat
# v.h
# ignor
# environ
# rent
# at birmingham university librari
# augustson
# technological commun
# 584
# chemical abstract service
# condens
# sage
# tabul
# ofc
# 486
# tefko
# brewster
# straight
# leimkuhl
# youth
# predecessor
# s.
# what makes an automatic keyword classification effect
# factor analysi
# 1124
# advisor
# barton
# cip
# matthew
# 2050
# inadvert
# scale photocopying servic
# supposedli
# academic library build
# rowland
# grotzing
# placement
# chapter
# ninth collective period
# searching cost
# deriv
# problemat
# the evalu
# current list
# peter
# cook
# gelberg
# 786
# r.g
# shreider
# my
# the united states steel corpor
# science citation index
# the project
# stanford university librari
# 1088
# mixtur
# 692
# whelan
# overproduct
# measur
# national bureau
# enjoy
# one million titl
# switch
# unmotiv
# 467
# harari
# monthli
# gain
# tantal
# 1346
# pocket
# drugdoc servic
# cic
# salvag
# boston athenaeum
# order divis
# initi
# urquhart
# restrict
# joc
# fayollat
# paradigm
# properti
# 1041
# retrieval system theori
# lyon
# it
# 498
# puzzl
# explicit
# had
# indefens
# dittmar
# arist
# 702
# banfield
# chemical compound
# demo
# announc
# developing computer catalog
# medusa
# testifi
# m.t.j
# trudi
# the review
# steiner
# edwin
# recur
# homogen
# mai
# biomedicin
# cornerston
# allegi
# systems philosophi
# manual  servic
# pretend
# the association factor
# pave
# jointli
# pen
# narin
# 1192
# frustrat
# scientific information exchang
# two on
# atop
# cain
# refresh
# 871
# hawaii
# core
# ferguson
# highly associative document retrieval system
# speed
# reservoir
# microfich
# 1147
# ctotal
# serebryanyi
# 247
# documentalist
# beneath
# context index
# 8186
# child
# 1344
# programm
# groombridg
# colleagu
# courag
# massachusetts institut
# vernon
# siegman
# prescrib
# 701
# stock
# minnesota bio
# public library chang
# gray
# monocl
# library information network
# ago
# bookstock
# national research council committe
# kunz
# introduc
# life
# 1776
# foreign
# pope
# objective measur
# 1259
# wainwright
# 1267
# functionalist
# 19
# reader
# medical library associ
# 228
# decreas
# j.d
# subdivis
# reference round t
# moss
# dynamic interact
# gluck
# patrick
# chapters ten
# lesliebeth
# re
# 594
# calm
# machlup
# droz
# the view
# the  integrated subject fil
# referral centerss
#         consult
# 395
# alchemi
# 343
# present
# converg
# but
# austin
# natural language retrieval system
# realm
# 311
# bibliographic entri
# gradi
# 405
# conjunct
# induc
# alleg
# nllst
# reader instruct
# circul
# keyboard
# 559
# ge
# who
# elsewher
# broad
# 1285
# messag
# mini
# subject specialist
# upsurg
# advanc
# sumner
# broker
# 253
# neurosci
# reed
# fullest
# congressmen
# holland
# epsilon
# autom
# 849
# done
# interlibrary loan involving academic librari
# the civic cultur
# shera
# southampton public librari
# proxim
# index
# term
# firschein
# mir
# finite automata theori
# countrywid
# periodical resourc
# program cont
# 1044
# cobol
# nona
# chemical structure storag
# shatter
# edg
# twelv
# colleg
# science museum
# librari
# hampstead laboratori
# the international meet
# 5
# iupac
# religi
# chase
# folger
# the ohio
# corporate head
# 884
# nonprint media
# 534
# chemical abstracts condensates data bas
# sector
# 139
# at
# dean jess
# tottenham
# later
# avram
# state information system
# stephani
# kuney
# cataloging rul
# name compress
# explos
# electronics engin
# 109
# sampl
# stagnant
# martino
# modern organ
# novemb
# nonmetric
# hypothesi
# nonfeder
# minuscul
# librarian
# readable bibliographic
# data bas
# reinventori
# usualx2
# 1985
# 1323
# news servic
# research literature us
# tefko
# perk
# heller
# georgia information dissemination
# cent
# automatic identif
# 307
# battl
# g.
# loui
# constantli
# statist
# replic
# five year
# locu
# the user
# interfac
# remnant
# obtain
# social symbol
# biggest
# mors
# 399
# quantitative measur
# sort
# an operations research studi
# notion
# coffman
# no
# alphanumeric data
# inherit
# optimum procedur
# national docu
# reassembl
# marvel
# 4020
# semiconductor
# physics literatur
# 853
# peopl
# power
# new methodolog
# bendix
# chiral
# decemb
# 1954
# assur
# becam
# bhattacharyya
# imperfect
# converting systematic nam
# ed
# lawrenc
# avalanch
# cheney
# library catalog cards produc
# jesse shera
# lose
# nurs
# nirvana
# 1169
# sear
# information ne
# filter
# recal
# fau
# term usag
# want
# upbring
# merton
# photo
# 127
# afford
# comment
# 1177
# myth
# supposit
# junior college librari
# its adequaci
# eleph
# amid
# 1176
# langloi
# line  serials control system
# elman
# pushkin
# ringdoc
# vysotskii
# ukranian
# undecid
# improp
# rare
# information center administr
# economic premis
# 40
# avant
# arthur
# shenderov
# underway
# static
# 723
# bloor
# four
# imparti
# the cranfield test
# nobl
# 1425
# 298
# b.c
# discrimin
# development engin
# social scientist
# reverber
# 1082
# signal
# accustom
# 946
# cabl
# a.k
# universal
# decimal classif
# cater
# l.a
# 1393
# negoti
# leiter
# artifici
# 493
# 708
# zero
# extent
# exegesi
# 1469
# fletcher
# preliminary draft
# colorado academic
# libraries book processing cent
# myrna
# information
# center manag
# mm microfilm
# oversel
# american public librari
# indexing consist
# leisur
# 683
# commmerci
# virginia
# eleanor
# shaw
# information storag
# 591
# byrd
# rais
# technological publ
# computer manipul
# tradeoff
# the national science librari
# an assess
# profus
# general purpose software system
# management misinformation system
# recours
# 1371
# presani
# not
# cox
# lean
# 736
# standard cost
# reassess
# american
# fleme
# attract
# technical information cent
# research park
# 967
# what information dissemination studies imply concern
# ful
# dinosauru
# conceiv
# handl
# gouldsmit
# housekeep
# 627
# 44
# 604
# lacuna
# ther
# c.e
# supar
# public health
# 104
# industri
# other new techniqu
# 496
# issn
# social sci
# alloc
# superb
# georg
# exactli
# been
# interwoven
# sweden
# chemical literature continu
# 1027
# guttsman
# neglig
# arrearag
# twice
# subject rel
# the outlook
# urg
# international organ
# 1034
# mauric
# mechanical index
# chemical abstracts
# index
# the ambigu
# perceived ne
# international business machin
# data
# persist
# miss doreen fras
# design equ
# 472
# effort
# 1201
# los angeles counti
# 878
# ct
# costli
# 1270
# 868
# wynneedward
# possibl
# west
# african
# overdu
# backlog
# fact
# state system
# overnight
# practic
# services
#         network
# patient
# lipset
# markuson
# 869
# in may
# should
# stratifi
# major decision point
# 1300
# scientific pap
# 1240
# mar
# pauline
# tessi
# medical librari
# leed
# e.l
# citation measur
# selective information serv
# multipurpose retrieval language tool
# united states
# military academy librari
# klempner
# s.e
# versatil
# research librari
# carnegie librari
# title compression code access
# care
# schofield
# heritag
# two diverse medical literatur
# kowalski
# plural
# president roosevelt
# terminolog
# compress
# nonspecialti
# 440
# 750
# 671
# immroth
# omiss
# word associ
# machine commun
# fell
# marguerit
# 757
# perfect
# lin
# use data
# marriag
# only entries retriev
# taub
# yale
# medical librari
# bossuat
# sent
# dewey
# various
# delus
# research studi
# peck
# the information cont
# computerized retrieval
# system
# processing depart
# 481
# featur
# i.a
# index term frequ
# second international seminar
# freer
# scientific knowledg
# academician
# structural model
# efficient appl
# 267
# arena
# hundr
# radar
# rank distribut
# carnot
# accumul
# anyon
# indentifi
# seeking behavior
# al
# altscul
# appurten
# n.e
# expertis
# east
# discontinu
# 197
# workbook
# prognosi
# matthew effect
# prevail
# searching  condensates on
# title derivative indexing techniqu
# 1457
# graduate school
# serv
# uncorrupt
# kozumplik
# decod
# special refer
# cultur
# national hospital panel survey
# automation
# task forc
# place
# dym
# neurolog
# allow
# abundantli
# conduc
# develop
# on rational structur
# destroy
# 1167
# georgia institut
# plausibl
# howard
# snel
# james carpentier lectur
# coverage overlap
# user evalu
# the citation identifi
# welsh
# scene
# chemical
# document
# red cross
# endlessli
# spald
# activ
# project intrex
# polytechn
# immediaci
# user circulation requir
# kebler
# 80
# information transmiss
# dialog
# 482
# impedi
# epidemic process
# political sci
# natural sci
# transplant
# fame
# ration
# 281
# the ring index
# boulder
# t.l
# product
# herbert
# nickelsen
# sir karl
# 578
# essay
# epistemolog
# the workshop
# oldrich
# 1302
# growth point
# sharpen
# formalist
# densiti
# microtext
# milwauke
# 1421
# univers
# 479
# gouldner
# query expans
# catalog us
# 1003
# 860
# underdevelop
# 799
# the distribut
# scientific instru
# carnegie corpor
# interlibrary loan oper
# 851
# handler
# clay
# academic tradit
# realli
# automatisierte information retrieval dienst
# generated classification schem
# unsuccess
# rel
# permut
# world dynam
# bodley
# 266
# mechanized information cent
# national science found
# academic statu
# benefit
# an experi
# colon classif
# rothstein
# paris principl
# bailiwick
# w.w
# is
# m.l
# retain
# notif
# science librari
# ilo
# boolean
# randal
# mountain
# 938
# distinct
# disburs
# storag
# meier
# cost survey
# ture
# 1418
# miles
# smith
# side
# pretest
# april
# bond connection t
# quantit
# unforgiv
# instruct
# reclassif
# fold
# brain
# unpredict
# 928
# bath
# braun
# sperling
# salko
